# %%
import numpy as np

# %%
# perceptron
# https://vitalflux.com/perceptron-explained-using-python-example/

# gradient descent
# https://vitalflux.com/gradient-descent-explained-simply-with-examples/

# %%
Image("0.png")

# %%
Image("2.png")

# %%
Image("3.png")

# %%
Image("4.png") #흔히 사용하는? function 들 모음 원리 한번 이해해보는 시간 가지면 ㄱㅊ을듯.

# %%
def net_input(self, X):
    weighted_sum = np.dot(X, self.coef_[1:]) + self.coef_[0]
    
    return weighted_sum

# Net INput is sum of weighted input signals

# %%
# Activation function is fed
#the net input and the unit step function is executed 
#to determine the output.

# %%
def activation_function(self, X):
    weighted_sum = self.net_input(X)
    return np.where(weighted_sum >= 0.0, 1, 0)

# %%
# net_input 함수에다가 X를 사용한다.

# %%
from IPython.display import Image

# %%
Image("1.png")

# %%
# Prediction is made on the basis of output of activation function

def predict(self, X):
    return self.activation_function(X)

# %%
# Stochastic Gradient Descent

#1. Weights are updated based on each training examples.
#2. Learning of weights can continue for multiple iterations
#3. Learning rate needs to be defined

#Is it the training set?

def fit(self, X, y):
    rgen = np.random.RandomState(self.random_state)
    self.coef_ = rgen.normal(loc=0.0, scale = 0.01, size=1 + X.shape[1])
    for _ in range(self.n_iterations):
            for xi, expected_value in zip(X, y):
                    predicted_value = self.predict(xi)
                    self.coef_[1:] = self.coef_[1:] + self.learning_rate * (expected_value - predicted_value) * xi
                    self.coef_[0] = self.coef_[0] + self.learning_rate * (expected_value - predicted_value) * 1
                    
                    
# * I don't understand gradient descent -> It is need to some study

# %%
fit
# Out:
# <function __main__.fit(self, X, y)>

# %%
# Stochastic gradient descent is an iterative method for optimizing an
# objective function with suitable smoothness properties.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 rgen = np.random.RandomState(self.random_state)
#
# NameError: name 'self' is not defined

# %%
Image("6.svg")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 Image("6.svg")
#
# File ~/tensorflow-test/env/lib/python3.8/site-packages/IPython/core/display.py:948, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     945 self.embed = embed if embed is not None else (url is None)
#     947 if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# --> 948     raise ValueError("Cannot embed the '%s' image format" % (self.format))
#     949 if self.embed:
#     950     self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the 'svg' image format

# %%
#Gradient descent

# 미분

# 기울기

Image("6.png")

# cost 가 0에 수렴하는 기울기

# -일때는 + 방향으로 흘러가고 +일때는 - 방향으로 흘러간다

# %%
import tensorflow as tf

# %%
# * 코드로는 어떻게 구현할까?

#Minimize: Gradient Descent using derivative: W -= learning_rate * derivative

learning_rate = 0.1

gradient = tf.reduce_mean((W*X-Y) * X)

descent = W - learning_rate * gradient

update = W.assign(descent) # W := W 에서 W가 넘어감
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [53], in <cell line: 7>()
#       1 # * 코드로는 어떻게 구현할까?
#       2
#       3 #Minimize: Gradient Descent using derivative: W -= learning_rate * derivative
#       5 learning_rate = 0.1
# ----> 7 gradient = tf.reduce_mean((W*X-Y) * X)
#       9 descent = W - learning_rate * gradient
#      11 update = W.assign(descent)
#
# NameError: name 'W' is not defined

# %%
# 예제는 py 파일로 돌려보자.
